# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("vgsales.csv")
X_and_Y = df.values 
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df = df.drop(["Rank", "Name"], axis = 1)
df.shape
# Out:
# (16598, 9)

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (16291, 9)

# %%
df["Platform"][1]
# Out:
# 'NES'

# %%
console_list = ["2600", "3DO", "DC", "GC", "N64", "NES", "NG",
                "PCFX", "PS", "PS2", "PS3", "PS4", "SAT", "SCD",
                'SNES', 'TG16', 'Wii', 'WiiU', 'X360','XB', 'XBOne']
Handheld_list = ['3DS','DS','GB','GBA','GEN','GG','PSP','PSV','WS']

# %%
# for i in df["Platform"]:
#     if i in console_list:
df = df.replace(console_list,"Console")
df = df.replace(Handheld_list,"Handheld")   
df["Platform"].value_counts()
# Out:
# Console     9986
# Handheld    5154
# PC           938
# XOne         213
# Name: Platform, dtype: int64

# %%
dict(df["Publisher"].value_counts())
# Out:
# {'Electronic Arts': 1339,
#  'Activision': 966,
#  'Namco Bandai Games': 928,
#  'Ubisoft': 918,
#  'Konami Digital Entertainment': 823,
#  'THQ': 712,
#  'Nintendo': 696,
#  'Sony Computer Entertainment': 682,
#  'Sega': 632,
#  'Take-Two Interactive': 412,
#  'Capcom': 376,
#  'Atari': 347,
#  'Tecmo Koei': 338,
#  'Square Enix': 231,
#  'Warner Bros. Interactive Entertainment': 217,
#  'Disney Interactive Studios': 214,
#  'Midway Games': 196,
#  'Eidos Interactive': 196,
#  '505 Games': 192,
#  'Microsoft Game Studios': 189,
#  'Acclaim Entertainment': 184,
#  'D3Publisher': 183,
#  'Vivendi Games': 161,
#  'Codemasters': 150,
#  'Idea Factory': 128,
#  'Deep Silver': 121,
#  'Nippon Ichi Software': 104,
#  'Zoo Digital Publishing': 104,
#  'Unknown': 100,
#  'Majesco Entertainment': 90,
#  'LucasArts': 89,
#  'Rising Star Games': 85,
#  'Hudson Soft': 81,
#  'Banpresto': 73,
#  'Crave Entertainment': 71,
#  'Bethesda Softworks': 69,
#  'Atlus': 67,
#  'Virgin Interactive': 62,
# ...

# %%
pub_dict = ['Electronic Arts',
 'Activision',
 'Namco Bandai Games',
 'Ubisoft',
 'Konami Digital Entertainment',
 'THQ',
 'Nintendo',
 'Sony Computer Entertainment',
 'Sega',
 'Take-Two Interactive']
pub = {'Electronic Arts': 1339,
 'Activision': 966,
 'Namco Bandai Games': 928,
 'Ubisoft': 918,
 'Konami Digital Entertainment': 823,
 'THQ': 712,
 'Nintendo': 696,
 'Sony Computer Entertainment': 682,
 'Sega': 632,
 'Take-Two Interactive': 412}
sums = 0

for key, value in pub.items():
    sums += value
    
sums
# Out:
# 8108

# %%
df = df.loc[df['Publisher'].isin(pub_dict)]

# %%
df.shape
# Out:
# (8108, 9)

# %%
df = df.reset_index(drop = True)

# %%
df
# Out:
#       Platform    Year         Genre                    Publisher  NA_Sales  \
# 0      Console  2006.0        Sports                     Nintendo     41.49
# 1      Console  1985.0      Platform                     Nintendo     29.08
# 2      Console  2008.0        Racing                     Nintendo     15.85
# 3      Console  2009.0        Sports                     Nintendo     15.75
# 4     Handheld  1996.0  Role-Playing                     Nintendo     11.27
# ...        ...     ...           ...                          ...       ...
# 8103  Handheld  2014.0        Action           Namco Bandai Games      0.00
# 8104  Handheld  2006.0        Puzzle  Sony Computer Entertainment      0.00
# 8105   Console  2003.0        Puzzle                      Ubisoft      0.01
# 8106        PC  2004.0     Adventure                      Ubisoft      0.01
# 8107   Console  2008.0        Racing                   Activision      0.00
#
#       EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
df.to_csv("preprocess.data.csv")

# %% [markdown]
# #### Encoding

# %%
#Encode Genre
genre_values = df['Genre'].value_counts().keys().tolist()
genre_list = []
for each in df.Genre:

    genre_list.append(genre_values.index(each))
    
df["Genre_encoding"] = genre_list

#Encode Publisher
publisher_values = df['Publisher'].value_counts().keys().tolist()
publisher_list = []
for each in df.Publisher:

    publisher_list.append(publisher_values.index(each))
    
df["Publisher Encoding"] = publisher_list

#Encode Platform
platform_values = df['Platform'].value_counts().keys().tolist()
platform_list = []
for each in df.Platform:

    platform_list.append(platform_values.index(each))
    
df["Platform Encoding"] = platform_list
publisher_values = df['Publisher'].value_counts().keys().tolist()

# %%
df.head()
# Out:
#    Platform    Year         Genre Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0   Console  2006.0        Sports  Nintendo     41.49     29.02      3.77
# 1   Console  1985.0      Platform  Nintendo     29.08      3.58      6.81
# 2   Console  2008.0        Racing  Nintendo     15.85     12.88      3.79
# 3   Console  2009.0        Sports  Nintendo     15.75     11.01      3.28
# 4  Handheld  1996.0  Role-Playing  Nintendo     11.27      8.89     10.22
#
#    Other_Sales  Global_Sales  Genre_encoding  Publisher Encoding  \
# 0         8.46         82.74               1                   6
# 1         0.77         40.24               6                   6
# 2         3.31         35.82               4                   6
# 3         2.96         33.00               1                   6
# 4         1.00         31.37               5                   6
#
#    Platform Encoding
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# ...

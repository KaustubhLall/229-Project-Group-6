# %%
import scipy.io as sio
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import time
import seaborn as sns
import scipy.stats as stats

# %%
df = pd.read_csv("preprocess_data.csv")
df.head()
# Out:
#    Unnamed: 0  Platform    Year         Genre Publisher  NA_Sales  EU_Sales  \
# 0           0   Console  2006.0        Sports  Nintendo     41.49     29.02
# 1           1   Console  1985.0      Platform  Nintendo     29.08      3.58
# 2           2   Console  2008.0        Racing  Nintendo     15.85     12.88
# 3           3   Console  2009.0        Sports  Nintendo     15.75     11.01
# 4           4  Handheld  1996.0  Role-Playing  Nintendo     11.27      8.89
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      3.77         8.46         82.74
# 1      6.81         0.77         40.24
# 2      3.79         3.31         35.82
# 3      3.28         2.96         33.00
# 4     10.22         1.00         31.37

# %%
pub_values_list = df['Publisher'].value_counts().keys().tolist()
publisher_avg_global_sales = []
for i in pub_values_list:
    entries = df.loc[df['Publisher'] == i]
    publisher_avg_global_sales.append(entries['Global_Sales'].sum()/len(entries))

zipped = zip(pub_values_list,publisher_avg_global_sales)
sorted_zipped = list(sorted(zipped,key = lambda x:x[1]))
publisher_list = []
pub_global_list = []
for s in sorted_zipped:
    publisher_list.append(s[0])
    pub_global_list.append(s[1])

# %%
plat_values_list = df['Platform'].value_counts().keys().tolist()
platform_avg_global_sales = []
for i in plat_values_list:
    entries = df.loc[df['Platform'] == i]
    platform_avg_global_sales.append(entries["Global_Sales"].sum()/len(entries))

zipped = zip(plat_values_list,platform_avg_global_sales)
sorted_zipped = list(sorted(zipped,key = lambda x:x[1]))
plat_list = []
plat_global_list = []
for each in sorted_zipped:
    plat_list.append(each[0])
    plat_global_list.append(each[1])

# %%
gen_values_list = df['Genre'].value_counts().keys().tolist()
gen_avg_global_sales = []
for i in gen_values_list:
    entries = df.loc[df['Genre'] == i]
    gen_avg_global_sales.append(entries['Global_Sales'].sum()/len(entries))

zipped = zip(gen_values_list,gen_avg_global_sales)
sorted_zipped = list(sorted(zipped,key = lambda x:x[1]))
genre_list = []
genre_global_list = []
for s in sorted_zipped:
    genre_list.append(s[0])
    genre_global_list.append(s[1])
#print(gen_values_list)

# %%
plt.figure(figsize = (12, 12))
p1 = plt.barh(plat_list, plat_global_list, color='r')
p2 = plt.barh(genre_list, genre_global_list, color='g')
p3 = plt.barh(publisher_list, pub_global_list, color='y')
plt.xlabel('Global Sales')
plt.ylabel('Platform, Genre, Publisher')  
plt.legend([ 'Platform','Genre', 'Publisher'], loc="best")
plt.show()

# %%
pub_values_list = df['Publisher'].value_counts().keys().tolist()
publisher_avg_eu_sales = []
for i in pub_values_list:
    entries = df.loc[df['Publisher'] == i]
    publisher_avg_eu_sales.append(entries['EU_Sales'].sum()/len(entries))

zipped = zip(pub_values_list,publisher_avg_eu_sales)
sorted_zipped = list(sorted(zipped,key = lambda x:x[1]))
publisher_list = []
pub_eu_list = []
for s in sorted_zipped:
    publisher_list.append(s[0])
    pub_eu_list.append(s[1])
    
    
plat_values_list = df['Platform'].value_counts().keys().tolist()
platform_avg_eu_sales = []
for i in plat_values_list:
    entries = df.loc[df['Platform'] == i]
    platform_avg_eu_sales.append(entries["EU_Sales"].sum()/len(entries))

zipped = zip(plat_values_list,platform_avg_eu_sales)
sorted_zipped = list(sorted(zipped,key = lambda x:x[1]))
plat_list = []
plat_eu_list = []
for each in sorted_zipped:
    plat_list.append(each[0])
    plat_eu_list.append(each[1])
    
gen_values_list = df['Genre'].value_counts().keys().tolist()
gen_avg_eu_sales = []
for i in gen_values_list:
    entries = df.loc[df['Genre'] == i]
    gen_avg_eu_sales.append(entries['EU_Sales'].sum()/len(entries))

zipped = zip(gen_values_list,gen_avg_eu_sales)
sorted_zipped = list(sorted(zipped,key = lambda x:x[1]))
genre_list = []
genre_eu_list = []
for s in sorted_zipped:
    genre_list.append(s[0])
    genre_eu_list.append(s[1])

# %%
plt.figure(figsize = (12, 12))
p1 = plt.barh(plat_list, plat_eu_list, color='r')
p2 = plt.barh(genre_list, genre_eu_list, color='g')
p3 = plt.barh(publisher_list, pub_eu_list, color='y')
plt.xlabel('European Sales')
plt.ylabel('Platform, Genre, Publisher')  
plt.legend([ 'Platform','Genre', 'Publisher'], loc="best")
plt.show()

# %%
pub_values_list = df['Publisher'].value_counts().keys().tolist()
publisher_avg_na_sales = []
for i in pub_values_list:
    entries = df.loc[df['Publisher'] == i]
    publisher_avg_na_sales.append(entries['NA_Sales'].sum()/len(entries))

zipped = zip(pub_values_list,publisher_avg_na_sales)
sorted_zipped = list(sorted(zipped,key = lambda x:x[1]))
publisher_list = []
pub_na_list = []
for s in sorted_zipped:
    publisher_list.append(s[0])
    pub_na_list.append(s[1])
    
    
plat_values_list = df['Platform'].value_counts().keys().tolist()
platform_avg_na_sales = []
for i in plat_values_list:
    entries = df.loc[df['Platform'] == i]
    platform_avg_na_sales.append(entries["NA_Sales"].sum()/len(entries))

zipped = zip(plat_values_list,platform_avg_na_sales)
sorted_zipped = list(sorted(zipped,key = lambda x:x[1]))
plat_list = []
plat_na_list = []
for each in sorted_zipped:
    plat_list.append(each[0])
    plat_na_list.append(each[1])
    
gen_values_list = df['Genre'].value_counts().keys().tolist()
gen_avg_na_sales = []
for i in gen_values_list:
    entries = df.loc[df['Genre'] == i]
    gen_avg_na_sales.append(entries['NA_Sales'].sum()/len(entries))

zipped = zip(gen_values_list,gen_avg_na_sales)
sorted_zipped = list(sorted(zipped,key = lambda x:x[1]))
genre_list = []
genre_na_list = []
for s in sorted_zipped:
    genre_list.append(s[0])
    genre_na_list.append(s[1])

# %%
plt.figure(figsize = (12, 12))
p1 = plt.barh(plat_list, plat_na_list, color='r')
p2 = plt.barh(genre_list, genre_na_list, color='g')
p3 = plt.barh(publisher_list, pub_na_list, color='y')
plt.xlabel('North American Sales')
plt.ylabel('Platform, Genre, Publisher')  
plt.legend([ 'Platform','Genre', 'Publisher'], loc="best")
plt.show()

# %%
pub_values_list = df['Publisher'].value_counts().keys().tolist()
publisher_avg_jp_sales = []
for i in pub_values_list:
    entries = df.loc[df['Publisher'] == i]
    publisher_avg_jp_sales.append(entries['NA_Sales'].sum()/len(entries))

zipped = zip(pub_values_list,publisher_avg_jp_sales)
sorted_zipped = list(sorted(zipped,key = lambda x:x[1]))
publisher_list = []
pub_jp_list = []
for s in sorted_zipped:
    publisher_list.append(s[0])
    pub_jp_list.append(s[1])
    
    
plat_values_list = df['Platform'].value_counts().keys().tolist()
platform_avg_jp_sales = []
for i in plat_values_list:
    entries = df.loc[df['Platform'] == i]
    platform_avg_jp_sales.append(entries["NA_Sales"].sum()/len(entries))

zipped = zip(plat_values_list,platform_avg_jp_sales)
sorted_zipped = list(sorted(zipped,key = lambda x:x[1]))
plat_list = []
plat_jp_list = []
for each in sorted_zipped:
    plat_list.append(each[0])
    plat_jp_list.append(each[1])
    
gen_values_list = df['Genre'].value_counts().keys().tolist()
gen_avg_jp_sales = []
for i in gen_values_list:
    entries = df.loc[df['Genre'] == i]
    gen_avg_jp_sales.append(entries['NA_Sales'].sum()/len(entries))

zipped = zip(gen_values_list,gen_avg_jp_sales)
sorted_zipped = list(sorted(zipped,key = lambda x:x[1]))
genre_list = []
genre_jp_list = []
for s in sorted_zipped:
    genre_list.append(s[0])
    genre_jp_list.append(s[1])

# %%
plt.figure(figsize = (12, 12))
p1 = plt.barh(plat_list, plat_jp_list, color='r')
p2 = plt.barh(genre_list, genre_jp_list, color='g')
p3 = plt.barh(publisher_list, pub_jp_list, color='y')
plt.xlabel('Japan Region Sales')
plt.ylabel('Platform, Genre, Publisher')  
plt.legend([ 'Platform','Genre', 'Publisher'], loc="best")
plt.show()

# %%
#Encode Genre
genre_values = df['Genre'].value_counts().keys().tolist()
genre_list = []
for each in df.Genre:

    genre_list.append(genre_values.index(each))
    
df["Genre_encoding"] = genre_list

#Encode Publisher
publisher_values = df['Publisher'].value_counts().keys().tolist()
publisher_list = []
for each in df.Publisher:

    publisher_list.append(publisher_values.index(each))
    
df["Publisher Encoding"] = publisher_list

#Encode Platform
platform_values = df['Platform'].value_counts().keys().tolist()
platform_list = []
for each in df.Platform:

    platform_list.append(platform_values.index(each))
    
df["Platform Encoding"] = platform_list
publisher_values = df['Publisher'].value_counts().keys().tolist()

# %%
df.head()
# Out:
#    Unnamed: 0  Platform    Year         Genre Publisher  NA_Sales  EU_Sales  \
# 0           0   Console  2006.0        Sports  Nintendo     41.49     29.02
# 1           1   Console  1985.0      Platform  Nintendo     29.08      3.58
# 2           2   Console  2008.0        Racing  Nintendo     15.85     12.88
# 3           3   Console  2009.0        Sports  Nintendo     15.75     11.01
# 4           4  Handheld  1996.0  Role-Playing  Nintendo     11.27      8.89
#
#    JP_Sales  Other_Sales  Global_Sales  Genre_encoding  Publisher Encoding  \
# 0      3.77         8.46         82.74               1                   6
# 1      6.81         0.77         40.24               6                   6
# 2      3.79         3.31         35.82               4                   6
# 3      3.28         2.96         33.00               1                   6
# 4     10.22         1.00         31.37               5                   6
#
#    Platform Encoding
# 0                  0
# ...

# %%
years_old = 2016 - df["Year"]
df["Year"] = years_old

# %%
df.head()
# Out:
#    Unnamed: 0  Platform  Year         Genre Publisher  NA_Sales  EU_Sales  \
# 0           0   Console  10.0        Sports  Nintendo     41.49     29.02
# 1           1   Console  31.0      Platform  Nintendo     29.08      3.58
# 2           2   Console   8.0        Racing  Nintendo     15.85     12.88
# 3           3   Console   7.0        Sports  Nintendo     15.75     11.01
# 4           4  Handheld  20.0  Role-Playing  Nintendo     11.27      8.89
#
#    JP_Sales  Other_Sales  Global_Sales  Genre_encoding  Publisher Encoding  \
# 0      3.77         8.46         82.74               1                   6
# 1      6.81         0.77         40.24               6                   6
# 2      3.79         3.31         35.82               4                   6
# 3      3.28         2.96         33.00               1                   6
# 4     10.22         1.00         31.37               5                   6
#
#    Platform Encoding
# 0                  0
# 1                  0
# ...

# %%
#platform sorting
platform_global_sales = []
platform_release_year = []
for i in range(len(Genre)):
    if Genre[i] == "Platform":
        platform_global_sales.append(df["Global_Sales"][i])
        platform_release_year.append(df["Year"][i])
#platform sales
m,n = np.polyfit(platform_release_year, platform_global_sales, 1)
plt.scatter(platform_release_year, platform_global_sales, marker = '*')
x = np.arange(0,50,1) 
y = m * x + n

plt.title('Platform Gnere games Global Sales vs Years since release')
plt.xlabel('Years Since Release')
plt.ylabel('Global Sales (millions)')
plt.plot(x, y, color = "red")

# %%
#platform sorting
shooter_global_sales = []
shooter_release_year = []
for i in range(len(Genre)):
    if Genre[i] == "Shooter":
        shooter_global_sales.append(df["Global_Sales"][i])
        shooter_release_year.append(df["Year"][i])
#platform sales
m,n = np.polyfit(shooter_release_year, shooter_global_sales, 1)
plt.scatter(shooter_release_year, shooter_global_sales, marker = '*')
x = np.arange(0,50,1) 
y = m * x + n

plt.title('Shooter Gnere games Global Sales vs Years since release')
plt.xlabel('Years Since Release')
plt.ylabel('Global Sales (millions)')
plt.plot(x, y, color = "red")

# %%
#linear regression model
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import mean_absolute_error

model = linear_model.LogisticRegression(C=1.0)
def feature(sale,years):
    avg = sum(sale)/len(sale)
    X = []
    y = []
    for year in years:
        X.append([1,year])
    for s in sale:
        if s > avg:
            y.append(1)
        else:
            y.append(0)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle=True)
    model.fit(X_train,y_train)
    pred=model.predict(X_test)
    
    return sum(pred == y_test)/len(pred)

# %%
print("The accuracy of prediction for Shooter Genre games: ", feature(shooter_global_sales,shooter_release_year))
print("The accuracy of prediction for Shooter Genre games: ", feature(platform_global_sales,platform_release_year))
# Out:
# The accuracy of prediction for Shooter Genre games:  0.7426470588235294
# The accuracy of prediction for Shooter Genre games:  0.7830188679245284
# D:\Users\bic01\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# D:\Users\bic01\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
